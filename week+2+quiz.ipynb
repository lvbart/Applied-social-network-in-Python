# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G3 = nx.Graph()
G3.add_edges_from([
    ('F','A'),
    ('F','B'),
    ('F','C'),
    ('F','D'),
    ('F','E'),
    ('A','B'),
    ('B','C'),
    ('C','D'),
    ('D','E'),
    ('E','A'),
    ('A','D'),
    ('A','C'),
])
nx.draw_networkx(G3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.clustering(G3,'F')
# Out:
# 0.7

# %%
nx.average_clustering(G3)
# Out:
# 0.8444444444444444

# %%
nx.transitivity(G3)
# Out:
# 0.7894736842105263

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G4 = nx.Graph()
G4.add_edges_from([
    ('B','A'),
    ('C','A'),
    ('D','A'),
    ('E','A'),
    ('F','A'),
    ('G','A'),
    ('H','A'),
    ('I','A'),
    ('B','C'),
    ('D','E'),
    ('F','G'),
    ('H','I'),
])
nx.draw_networkx(G4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.average_clustering(G4)
# Out:
# 0.9047619047619047

# %%
nx.transitivity(G4)
# Out:
# 0.3333333333333333

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G5 = nx.Graph()
G5.add_edges_from([
    ('B','A'),
    ('C','A'),
    ('D','A'),
    ('E','A'),
    ('B','C'),
    ('B','D'),
    ('D','B'),
    ('C','D'),
    ('D','E'),
    ('B','E'),
    ('B','F'),
    ('C','G'),
    ('D','H'),
    ('E','I')
])
nx.draw_networkx(G5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.average_clustering(G5)
# Out:
# 0.3148148148148148

# %%
nx.transitivity(G5)
# Out:
# 0.5526315789473685

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G6 = nx.Graph()
G6.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'D'), ('C', 'E'), ('E', 'D'), ('D', 'G'), ('E', 'G'), ('G', 'F')])
nx.draw_networkx(G6)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.radius(G6)
# Out:
# 2

# %%
nx.diameter(G6)
# Out:
# 4

# %%
T = nx.bfs_tree(G6,'A')
T.edges()
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'G'), ('G', 'F')]

# %%
nx.eccentricity(G6)
# Out:
# {'A': 4, 'B': 3, 'C': 3, 'D': 2, 'E': 2, 'F': 4, 'G': 3}

# %%
nx.center(G6)
# Out:
# ['D', 'E']

# %%
nx.periphery(G6)
# Out:
# ['A', 'F']

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G7 = nx.DiGraph()
G7.add_edges_from([
    ('A','B'),
    ('A','C'),
    ('B','C'),
    ('C','B'),
    ('E','B'),
    ('D','C'),
    ('C','D')
])
nx.draw_networkx(G7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.is_strongly_connected(G7)
# Out:
# False

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G8 = nx.DiGraph()
G8.add_edges_from([
    ('B','A'),
    ('A','B'),
    ('A','C'),
    ('C','A'),
    ('A','D'),
    ('D','E'),
    ('E','C'),
    ('B','C')
])
nx.draw_networkx(G8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.is_strongly_connected(G8)
# Out:
# True

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G9 = nx.DiGraph()
G9.add_edges_from([
    ('B','A'),
    ('A','C'),
    ('C','B'),
    ('A','D')
])
nx.draw_networkx(G9)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.is_strongly_connected(G9)
# Out:
# False

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G10 = nx.Graph()
G10.add_edges_from([
    ('A', 'B'), ('A', 'C'), ('A', 'F'), ('C', 'F'), ('C', 'B'), ('E', 'B'), ('D', 'B'), ('E', 'F'), ('C', 'E'),
    ('D', 'E'), ('E', 'G'), ('E', 'H'), ('G', 'H'), ('G', 'M'), ('H', 'M'), ('G', 'K'), ('M', 'K'),('K','N'),
    ('H','N')
])
nx.draw_networkx(G10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.node_connectivity(G10)
# Out:
# 1

# %%
nx.edge_connectivity(G10)
# Out:
# 2

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

G11 = nx.DiGraph()
G11.add_edges_from([
    ('D','A'),
    ('D','B'),
    ('A','C'),
    ('B','A'),
    ('C','B'),
    ('C','E'),
    ('E','F'),
    ('E','H'),
    ('J','E'),
    ('H','J'),
    ('F','H'),
    ('H','K'),
    ('K','J'),
    ('F','K'),
    ('G','K'),
    ('F','G')
])
nx.draw_networkx(G11)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sorted(nx.all_simple_paths(G11,'D','K'))
# Out:
# [['D', 'A', 'C', 'E', 'F', 'G', 'K'],
#  ['D', 'A', 'C', 'E', 'F', 'H', 'K'],
#  ['D', 'A', 'C', 'E', 'F', 'K'],
#  ['D', 'A', 'C', 'E', 'H', 'K'],
#  ['D', 'B', 'A', 'C', 'E', 'F', 'G', 'K'],
#  ['D', 'B', 'A', 'C', 'E', 'F', 'H', 'K'],
#  ['D', 'B', 'A', 'C', 'E', 'F', 'K'],
#  ['D', 'B', 'A', 'C', 'E', 'H', 'K']]

# %%
nx.minimum_node_cut(G11,'E','K')
# Out:
# {'F', 'H'}

# %%
nx.minimum_edge_cut(G11,'E','K')
# Out:
# {('E', 'F'), ('H', 'K')}

# %%
import networkx as nx

# This line must be commented out when submitting to the autograder
# !head email_network.txt
# Out:
# #Sender	Recipient	time
# 1	2	1262454010
# 1	3	1262454010
# 1	4	1262454010
# 1	5	1262454010
# 1	6	1262454010
# 1	7	1262454010
# 1	8	1262454010
# 1	9	1262454010
# 1	10	1262454010

# %%
G = nx.read_edgelist('email_network.txt', delimiter='\t', data=[('time', int)], create_using=nx.MultiDiGraph())

# %%
import networkx as nx
import numpy as np
import pandas as pd
# %matplotlib notebook

nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">
